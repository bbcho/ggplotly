# %%
from ggplotly import *
import pandas as pd

# %%
data()
# Out:
# ['commodity_prices',
#  'diamonds',
#  'economics',
#  'economics_long',
#  'faithfuld',
#  'iris',
#  'luv_colours',
#  'midwest',
#  'mpg',
#  'msleep',
#  'mtcars',
#  'presidential',
#  'seals',
#  'txhousing',
#  'us_flights',
#  'us_flights_edges',
#  'us_flights_nodes']

# %%
df = data('commodity_prices')

# %%
df
# Out:
#               date series   value
# 0       2007-01-02   CL01   61.05
# 1       2007-01-02   CL02   62.38
# 2       2007-01-02   CL03   63.26
# 3       2007-01-02   CL04   63.95
# 4       2007-01-02   CL05   64.54
# ...            ...    ...     ...
# 692624  2023-10-19  MJP02  110.00
# 692625  2023-10-19  MJP03  110.00
# 692626  2023-10-19  MJP04     NaN
# 692627  2023-10-19  MJP05     NaN
# 692628  2023-10-19  MJP06     NaN
#
# [692629 rows x 3 columns]

# %%
df.date = pd.to_datetime(df.date)

# %%
df = df[df.series == 'CL01'].set_index('date').value

# %%
df
# Out:
# date
# 2007-01-02    61.05
# 2007-01-03    58.32
# 2007-01-04    55.59
# 2007-01-05    56.31
# 2007-01-08    56.09
#               ...
# 2023-10-13    87.69
# 2023-10-16    86.66
# 2023-10-17    86.66
# 2023-10-18    88.32
# 2023-10-19    89.37
# Name: value, Length: 4233, dtype: float64

# %%
ggplot(df) + geom_line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/Projects/ggplotly/ggplotly/ggplot.py in ?(self)
#      86     def __add__(self, other):
#      87         self.add_component(other)
#      88         return self.copy()
#
# ~/Projects/ggplotly/ggplotly/ggplot.py in ?(self)
#
# ~/Projects/ggplotly/ggplotly/geoms/geom_line.py in ?(self, fig, data, row, col)
#      87             color="line_color",
#      88             size="line_width",
#      89         )
#      90
# ---> 91         self._transform_fig(plot, fig, data, payload, color_targets, row, col)
#      92
#      93         # Restore fill parameter if it was removed
#      94         if plotly_fill is not None:
#
# ~/Projects/ggplotly/ggplotly/geoms/geom_base.py in ?(self, plot, fig, data, payload, color_targets, row, col, **layout)
#     232     def _transform_fig(
#     233         self, plot, fig, data, payload, color_targets, row, col, **layout
#     234     ):
#     235         # Create aesthetic mapper for this geom, passing global maps for faceting
# --> 236         mapper = AestheticMapper(
#     237             data, self.mapping, self.params, self.theme,
#     238             global_color_map=self._global_color_map,
#     239             global_shape_map=self._global_shape_map
#
# ~/Projects/ggplotly/ggplotly/aesthetic_mapper.py in ?(self, data, mapping, params, theme, global_color_map, global_shape_map, validate)
#     126         self.global_shape_map = global_shape_map
#     127         self.validate = validate
#     128
#     129         # Cache column names as frozenset for O(1) lookups
# --> 130         self._column_set = frozenset(data.columns) if data is not None else frozenset()
#     131
#     132         # Instance-level cache for style properties
#     133         self._style_props_cache = None
#
# ~/Projects/ggplotly/env/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'
